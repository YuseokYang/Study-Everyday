# %% [markdown]
# <a href="https://colab.research.google.com/github/YuseokYang/Study-Everyday/blob/main/EDA_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pickle
import pandas as pd
filename = 'load.csv'

# %%
cols = None
data = []
with open(filename) as f:
  for line in f.readlines():
    vals = line.replace('\n', '').split(',')
    if cols is None:
      cols = vals
    else:
      data.append([float(x) for x in vals])
d0 = pd.DataFrame(data, columns = cols)
print(d0.dtypes)
d0
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# dtype: object
#          A       B       C        D      E
# 0    1.276  21.400  63.957  216.204  528.0
# 1    1.002  21.950  61.697  204.484  514.0
# 2    1.114  22.454  63.522  205.608  514.0
# 3    1.133  22.494  61.590  206.565  501.0
# 4    0.845  21.654  63.729  201.289  532.0
# ..     ...     ...     ...      ...    ...
# 495  1.060  20.585  60.653  208.990  501.0
# 496  1.163  22.629  62.278  200.712  497.0
# 497  1.029  21.705  62.311  209.684  517.0
# 498  1.114  21.473  65.710  212.078  506.0
# 499  1.199  21.586  64.273  208.358  500.0
#
# [500 rows x 5 columns]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Diabetes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df2.head()
# Out:
#    Glucose   BMI  Age  Outcome
# 0      148  33.6   50        1
# 1       85  26.6   31        0
# 2      183  23.3   32        1
# 3       89  28.1   21        0
# 4      137  43.1   33        1

# %%
df1 = df.fillna(0)

# %%
df2 = df[['Glucose', 'BMI', 'Age', 'Outcome']]

# %%
df2.head()
# Out:
#    Glucose   BMI  Age  Outcome
# 0      148  33.6   50        1
# 1       85  26.6   31        0
# 2      183  23.3   32        1
# 3       89  28.1   21        0
# 4      137  43.1   33        1

# %%
df2.describe()
# Out:
#           Glucose         BMI         Age     Outcome
# count  768.000000  768.000000  768.000000  768.000000
# mean   120.894531   31.992578   33.240885    0.348958
# std     31.972618    7.884160   11.760232    0.476951
# min      0.000000    0.000000   21.000000    0.000000
# 25%     99.000000   27.300000   24.000000    0.000000
# 50%    117.000000   32.000000   29.000000    0.000000
# 75%    140.250000   36.600000   41.000000    1.000000
# max    199.000000   67.100000   81.000000    1.000000

# %%
df3 = df2[~(df2[df2.columns[:-1]] == 0).any(axis=1)]

# %%
df3 = df2[~(df2[df2.columns[:-1]] == 0).any(axis=1)]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 752 entries, 0 to 767
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Glucose  752 non-null    int64
#  1   BMI      752 non-null    float64
#  2   Age      752 non-null    int64
#  3   Outcome  752 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 29.4 KB

# %%
(df3[df3.columns[:-1]]==0).sum()
# Out:
# Glucose    0
# BMI        0
# Age        0
# dtype: int64

# %%
df3.groupby('Outcome').mean()
# Out:
#             Glucose        BMI        Age
# Outcome
# 0        110.825820  30.876434  31.309426
# 1        142.488636  35.371970  37.015152

# %%
df3.groupby('Outcome').agg({'Glucose':'mean', 'BMI':'median', 'Age':'sum'})
# Out:
#             Glucose    BMI    Age
# Outcome
# 0        110.825820  30.10  15279
# 1        142.488636  34.25   9772

# %%
df3[df3['Outcome']==1].shape
df3[df3['Outcome']==0].shape
# Out:
# (488, 4)

# %%
df3.to_csv('clean_diabetes.csv', index=False)

# %%
df3['Outcome'].value_counts()
# Out:
# Outcome
# 0    488
# 1    264
# Name: count, dtype: int64
